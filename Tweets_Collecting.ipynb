# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
attributes_container = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('الببغاء since:2010-01-01 until:2022-12-12').get_items()):
    if i>10000:
        break
    attributes_container.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.sourceLabel, tweet.content])
    
# Creating a dataframe to load the list
df = pd.DataFrame(attributes_container, columns=["User", "Date Created", "Number of Likes", "Source of Tweet", "Tweet"])

# %%
df.tail(50)
# Out:
#                 User              Date Created  Number of Likes  \
# 70        XL_MoHaMeD 2016-09-13 12:49:08+00:00                0
# 71           _BiiBA_ 2016-06-11 23:32:34+00:00                0
# 72            RAOA__ 2016-06-10 15:21:58+00:00                0
# 73           Gerraxd 2016-05-28 14:20:50+00:00                0
# 74       ezzatelkiat 2016-05-05 23:25:50+00:00                0
# 75    Bar0000000000n 2016-03-25 13:50:41+00:00                0
# 76      giffunimages 2016-01-26 08:19:41+00:00                0
# 77          Guev2014 2016-01-26 08:04:31+00:00                1
# 78   mohamedghareb22 2015-08-22 01:17:27+00:00                0
# 79   AhmedKorayem_ak 2015-07-26 15:25:26+00:00                0
# 80    scorpiondenjer 2015-07-20 02:57:56+00:00                0
# 81        ahmed_adli 2015-06-17 01:04:14+00:00                0
# 82    hadeerofficial 2015-05-27 20:12:05+00:00                0
# 83            100XBO 2015-03-08 07:22:00+00:00                0
# ...

# %%
df["Tweet"].head(50)
# Out:
# 0     خيّروني بين موت وبقاء\nبين ان ارقص فوق الحبل\n...
# 1     والله هو سكر الي يتكلم مربيه من يومه فرخ ياخذ ...
# 2     الببغاء مره قبيح ومزعج وصراحه يخوفني شوي    ما...
# 3     #طفشانه سكر يرد ع التاق بطريقته 😂🙏🏼 https://t....
# 4     #جده_lلان احس اهل جدة كذا يصير فيهم 😂 https://...
# 5     @ayaayouch05 هدا راه كي الببغاء المهم يهدر وخل...
# 6     يومياً قتل واغتيالات وتصفية رجال ونساء هذا كله...
# 7     @Maya49489205 @soly_aziz @ScreenMix الأخت لازا...
# 8                             @hajjjm999 تعرف الببغاء 😂
# 9     شوفو توقعات ديال الببغاء ياربي اصدقو 🤲 https:/...
# 10    @68__na @_G4ll والله شوفي الببغاء ذا عندي من 4...
# 11    @menooo2023 هما حاطين قدامها كلام وهي زي الببغ...
# 12    سبحان الله .. \nهذا الطائر إسمه البفن الأطلسي ...
# 13    @fdcvccccc @chaQmQcha @L9arami كلهم موجودين تر...
# 14    والله اني سحبت على الببغاء سحبه وهو هاجد يعني ...
# 15    @Tu_Alghamdi فهي ناس كثير شفتهم ساذجين ولكن مث...
# 16    @hmm51 تكذب وتردد مثل الببغاء كم بطولة حصل علي...
# ...

# %%
df.to_csv(r'E:\Tweets Collecting about animals\1.csv', index=False, encoding='utf-8-sig')

# %%
import itertools

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="my_user_agent")
city ="Mekka"
country ="KSA"
loc = geolocator.geocode(city+','+ country)
print("latitude is :-" ,loc.latitude,"\nlongtitude is:-" ,loc.longitude)
# Out:
# latitude is :- 21.569730800000002
# longtitude is:- 39.12451434475113

# %%
df_city = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'البغبغان near:"Cairo" within:1000km').get_items(), 100))[['date', 'content','user_location']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [138], in <cell line: 1>()
# ----> 1 df_city = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
#       2     'البغبغان near:"Cairo" within:1000km').get_items(), 100))[['date', 'content','user_location']]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
df_city
# Out:
#                         date  \
# 0  2022-12-12 12:05:12+00:00
# 1  2022-12-12 06:00:46+00:00
# 2  2022-12-12 03:07:05+00:00
# 3  2022-12-11 13:31:43+00:00
# 4  2022-12-11 05:59:18+00:00
# ..                       ...
# 95 2020-10-31 20:44:18+00:00
# 96 2020-10-30 19:16:11+00:00
# 97 2020-10-27 14:52:16+00:00
# 98 2020-10-19 05:02:56+00:00
# 99 2020-10-16 13:26:58+00:00
#
#                                               content
# 0               @Noran_walid صباح بروح شعبان البغبغان
# 1   - ايه دا بجد انتِ من بورسعيد ؟ \n= اه بجد ليه ...
# 2   @FaresAyman_ العrص ده يبقى أبوك عشان معرفش يرب...
# 3   @HNasrIbrahim واخيرا خليك كدا واكتب ان الاهلي ...
# 4   @ahmed9oooo تصنيف ايه يا اهبل الي بيتحسب علي ا...
# ..                                                ...
# 95  سبحان من انطق البغبغان بنشيد الأبطال والهمه با...
# 96                      الحرب لو كلام البغبغان يكسب 🔞
# 97  الانجاز بس في حد ذاته وبجد عظيم♥️💪🏼\n\nان مايج...
# 98  @amrwaked مش فاكر 😁 الزهايمر اشتغل ولا هرمون ا...
# ...

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="my_user_agent")
city ="Cairo"
country ="Egypt"
loc = geolocator.geocode(city+','+ country)
print("latitude is :-" ,loc.latitude,"\nlongtitude is:-" ,loc.longitude)
# Out:
# latitude is :- 30.0443879
# longtitude is:- 31.2357257

# %%
loc = '30.0443879 , 31.2357257, 1000000km'
df_coord = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'البغبغان geocode:"{}"'.format(loc)).get_items(), 100000))[['user', 'date','content']]


df_coord['user_location'] =  df_coord['user'].apply(lambda x: x['location'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'user'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
len(df_coord)
# Out:
# 364

# %%
df_coord.tail(70)
# Out:
#                                                   user  \
# 294  {'username': 'mido704', 'id': 126130653, 'disp...
# 295  {'username': 'Hadeer_Achraf', 'id': 1271136007...
# 296  {'username': 'AMRMUSTAFAHASH', 'id': 624326081...
# 297  {'username': 'rbnasralla', 'id': 169412927, 'd...
# 298  {'username': 'MohamedOtaif', 'id': 263604515, ...
# ..                                                 ...
# 359  {'username': 'Ramiiaz', 'id': 341565295, 'disp...
# 360  {'username': 'Ramiiaz', 'id': 341565295, 'disp...
# 361  {'username': 'AhmedTawfiq', 'id': 63521047, 'd...
# 362  {'username': 'EsraaHussin', 'id': 175156873, '...
# 363  {'username': 'Mariumaz', 'id': 30588309, 'disp...
#
#                          date  \
# 294 2014-08-23 23:20:42+00:00
# 295 2014-08-18 15:05:19+00:00
# 296 2014-08-16 16:09:10+00:00
# 297 2014-08-11 17:54:07+00:00
# 298 2014-08-10 22:17:51+00:00
# ..                        ...
# 359 2011-09-23 00:54:03+00:00
# 360 2011-09-18 00:05:22+00:00
# ...

# %%
df_coord["user_location"].unique()
# Out:
# array(['', 'Jeddah - Saudi Arabia', 'جدة, المملكة العربية السعودية',
#        'Jeddah', 'جده - جازان ', 'بين شِهاب وزُوي', '𝐽𝑒𝑑𝑑𝑎ℎ💙',
#        'المملكة العربية السعودية 🇸🇦', 'Jeddah ❤ PA, Philadelphia',
#        'Kingdom of Saudi Arabia', 'الطائف, المملكة العربية ',
#        'Somewhere ..', 'الجزيرة العربية ',
#        'جدة, المملكة العربية السعودية.', 'المملكة العربية السعودية - جدة',
#        'Jeddah, Kingdom of Saudi Arabia', 'مكة المكرمة',
#        'بين دعاء آمي وحضنها ☁️✨.', 'Jazan واحياناً Hogwarts',
#        'Jeddah, Kingdom of Saudi Arabi', 'Jeddah.Taif', 'هدي الشام مكة ',
#        'جدّة Jeddah', 'السعودية العظمى', 'Jeddah, KSA - جدة، السعودية',
#        'السعودية - مكة المكرمة.  ', '#Jeddah ',
#        'جدة, المملكة العربية السعودية ', 'في أي مكان لكن قلبي بمكة❤',
#        'Jeddah & TX & Leeds  ', 'TAIF', 'Riyadh, Kingdom of Saudi Arabia',
#        'JEDDAH', 'Earth', 'saudi arabia, Riyadh', 'السعوديه جده',
#        'facbook', '  Great K.S.A -Jeddah and  (❤)', 'Riyadh',
# ...

# %%
بغبغان الكويكر ، الدرة الأمريكي

# %%
الدرة الهندي

# %%
المكاو

# %%
import arabicstopwords.arabicstopwords as stp
stp.is_stop('أحمد')
# Out:
# False

# %%
x = "أنا الذي نظر الأعمى إلى أدبي"
y = x.split(" ")
print(y)
#for i in x:
    #print(i)
    #y = stp.is_stop(i)
    #print(i)
    #print(y)
# Out:
# ['أنا', 'الذي', 'نظر', 'الأعمى', 'إلى', 'أدبي']

# %%
x = "أنا الذي نظر الأعمى إلى أدبي"
y = x.split(" ")
for i in y:
    stop = stp.is_stop(i)
    print(i,stop)
# Out:
# أنا True
# الذي True
# نظر False
# الأعمى False
# إلى True
# أدبي False

# %%
x = "أنا الذي نظر الأعمى إلى أدبي"
y = x.split(" ")
for i in y:
    stop = stp.is_stop(i)
    if stop == True:
        #print(i,stop)
        y.remove(i)
print(y)
# Out:
# ['الذي', 'نظر', 'الأعمى', 'أدبي']

# %%
x = "ومرهف سرت بين الجحفلين به حتى ضربت وموج الموت يلتطم"
y = x.split(" ")
for i in y:
    stop = stp.is_stop(i)
    if stop == True:
        #print(i,stop)
        y.remove(i)
print(y)
# Out:
# ['ومرهف', 'سرت', 'الجحفلين', 'حتى', 'ضربت', 'وموج', 'الموت', 'يلتطم']

# %%
text1 = "أنام ملء جفوني عن شواردها ويسهر الخلق جراها ويختصم"
text2 = "ومرهف سرت بين الجحفلين به حتى ضربت وموج الموت يلتطم"
x = text1.split(" ")
y = text2.split(" ")
print(x,y)
z = []
w = []
text = [x,y]
for i in text:
    if i == x:
        for i in x:
            stop = stp.is_stop(i)
    #print(stop)
            if stop == True:
        #print(i,stop)
                x.remove(i)
            elif stop == False:
        #print(i)
                z.append(i)
    else:
        if i == y:
            for i in y:
                stop = stp.is_stop(i)
    #print(stop)
                if stop == True:
        #print(i,stop)
                    y.remove(i)
                elif stop == False:
                    w.append(i)
print(z)
print(w)
z = " ".join(z)
w = " ".join(w)
print(z)
print(w)
# Out:
# ['أنام', 'ملء', 'جفوني', 'عن', 'شواردها', 'ويسهر', 'الخلق', 'جراها', 'ويختصم'] ['ومرهف', 'سرت', 'بين', 'الجحفلين', 'به', 'حتى', 'ضربت', 'وموج', 'الموت', 'يلتطم']
# ['أنام', 'ملء', 'جفوني', 'ويسهر', 'الخلق', 'جراها', 'ويختصم']
# ['ومرهف', 'سرت', 'ضربت', 'وموج', 'الموت', 'يلتطم']
# أنام ملء جفوني ويسهر الخلق جراها ويختصم
# ومرهف سرت ضربت وموج الموت يلتطم

# %%
text1 = "أنام ملء جفوني عن شواردها ويسهر الخلق جراها ويختصم"
text2 = "ومرهف سرت بين الجحفلين به حتى ضربت وموج الموت يلتطم"
x = text1.split(" ")
y = text2.split(" ")
lst = []
#print(x,y)
#z = []
#w = []
text = [x,y]
for i in text:
    for t in i:
        stop = stp.is_stop(t)
    #print(stop)
        if stop == True:
        #print(i,stop)
            i.remove(t)
        elif stop == False:
        #print(i)
            lst.append(t)
#print(x)
#print(y)
#w = " ".join(x)
z = " ".join(lst)
print(z)
#print(w)
#print(z)
# Out:
# أنام ملء جفوني ويسهر الخلق جراها ويختصم ومرهف سرت ضربت وموج الموت يلتطم

# %%
text1 = "أنام ملء جفوني عن شواردها ويسهر الخلق جراها ويختصم"
text2 = "ومرهف سرت بين الجحفلين به حتى ضربت وموج الموت يلتطم"
x = text1.split(" ")
y = text2.split(" ")
z = []
w = []
#print(x,y)
#z = []
#w = []
text = [x,y]
text3 = [text1,text2]
for i in text3:
    i = i.split(" ")
        for t in i:
        if t != "أحمد":
            i.append(t)
        else:
            i.remove(t)
    print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [161], in <cell line: 12>()
#      13 for t in i:
#      14     if t != "أحمد":
# ---> 15         i.append(t)
#      16     else:
#      17         i.remove(t)
#
# AttributeError: 'str' object has no attribute 'append'

# %%
for i in text3:
    print(i)
    i = i.split(" ")
    print(i)
# Out:
# أنام ملء جفوني عن شواردها ويسهر الخلق جراها ويختصم
# ['أنام', 'ملء', 'جفوني', 'عن', 'شواردها', 'ويسهر', 'الخلق', 'جراها', 'ويختصم']
# ومرهف سرت بين الجحفلين به حتى ضربت وموج الموت يلتطم
# ['ومرهف', 'سرت', 'بين', 'الجحفلين', 'به', 'حتى', 'ضربت', 'وموج', 'الموت', 'يلتطم']

# %%
#x = ["hello", "hel"]
#y = ["world", "wor"]
lst1 = []
lst2 = []
lst3 = [lst1,lst2]
#lst
p = [x, y]
for i,j in zip(p,lst3):
    for t in i:
        j.append(t)
    #print(lst3)
print(lst3)
#print(j)
# Out:
# [['أنام', 'ملء', 'جفوني', 'شواردها', 'ويسهر', 'الخلق', 'جراها', 'ويختصم'], ['ومرهف', 'سرت', 'الجحفلين', 'حتى', 'ضربت', 'وموج', 'الموت', 'يلتطم', 'أنام', 'ملء', 'جفوني', 'شواردها', 'ويسهر', 'الخلق', 'جراها', 'ويختصم', 'أنام', 'ملء', 'جفوني', 'شواردها', 'ويسهر', 'الخلق', 'جراها', 'ويختصم', 'أنام', 'ملء', 'جفوني', 'شواردها', 'ويسهر', 'الخلق', 'جراها', 'ويختصم', 'أنام', 'ملء', 'جفوني', 'شواردها', 'ويسهر', 'الخلق', 'جراها', 'ويختصم', 'أنام', 'ملء', 'جفوني', 'شواردها', 'ويسهر', 'الخلق', 'جراها', 'ويختصم', 'أنام', 'ملء', 'جفوني', 'شواردها', 'ويسهر', 'الخلق', 'جراها', 'ويختصم']]

# %%
x = "أنا الذي نظر الأعمى إلى أدبي"
y = x.split()
for i in y:
    if i =="أدبي":
        y.remove(i)
print(y)
# Out:
# ['أنا', 'الذي', 'نظر', 'الأعمى', 'إلى']

# %%
text2 = "ومرهف سرت بين الجحفلين به حتى ضربت وموج الموت يلتطم"

# %%
text = "أنا الذي نظر الأعمى إلى أدبي"
words = text.split(" ")
for word in words:
    stop_word = stp.is_stop(word)
    if stop_word == True:
        words.remove(stop_word)
print(words)
    #print(word, stop_word)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [94], in <cell line: 3>()
#       4     stop_word = stp.is_stop(word)
#       5     if stop_word == True:
# ----> 6         words.remove(stop_word)
#       7 print(words)
#
# ValueError: list.remove(x): x not in list

# %%
x = 2 
y = 3
if y > x:
    y = True
if y == True:
    print("Good")
# Out:
# Good
