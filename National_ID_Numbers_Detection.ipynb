# %%
#clone YOLOv5 and
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16078, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 16078 (delta 6), reused 9 (delta 1), pack-reused 16056
# Receiving objects: 100% (16078/16078), 14.64 MiB | 22.82 MiB/s, done.
# Resolving deltas: 100% (11038/11038), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 46.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.7/645.7 kB 42.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="XRcZB4HVUZw2RzVGB0EV")
project = rf.workspace("ahmad-essam-gvgib").project("national-id-vkdrw")
dataset = project.version(1).download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to national-id-1 in yolov5pytorch:: 100%|██████████| 2721/2721 [00:00<00:00, 5044.58it/s]

# %%
os.environ["DATASET_DIRECTORY"] = "/content/dataset"

# %%
# !python train.py --img 416 --batch 16 --epochs 50 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
#        0/49         0G     0.1228    0.01439          0         24        416:  10% 8/82 [01:31<13:11, 10.70s/it]

# %%
# !python train.py --img 416 --batch 16 --epochs 3 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# 2023-11-25 06:33:30.799866: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-25 06:33:30.799933: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-25 06:33:30.799974: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 50 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# 2023-11-21 12:00:36.121480: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-21 12:00:36.121591: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-21 12:00:36.121635: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
model = torch.hub.load('.', 'custom', path='/content/yolov5/runs/train/exp/weights/best.pt', source='local')
# Out:
# YOLOv5 🚀 v7.0-245-g3d8f004 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
import cv2

# %%
images = '/content/images/'

for img in os.listdir(images):
    try:
        img_path = os.path.join(images, img)
        result = model(img_path)
        result.show()
    except (OSError, cv2.error) as e:
        print(f"Error processing image {img}: {e}")
        continue
# Out:
# Error processing image 6.jpg: cannot identify image file '/content/images1/6.jpg'
# Error processing image 3.jpg: cannot identify image file '/content/images1/3.jpg'

# %%
model = torch.hub.load('.', 'custom', path='/content/best.pt', source='local')
# Out:
# YOLOv5 🚀 v7.0-245-g3d8f004 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
images = '/content/images1/'

for img in os.listdir(images):
    try:
        img_path = os.path.join(images, img)
        result = model(img_path)
        result.show()
    except (OSError, cv2.error) as e:
        print(f"Error processing image {img}: {e}")
        continue
# Out:
# Error processing image 0_jpg.rf.a7546d8c86cc0f6b05eba7605402852d.jpg: cannot identify image file '/content/images1/0_jpg.rf.a7546d8c86cc0f6b05eba7605402852d.jpg'
# Error processing image 0_jpg.rf.33492b06d74069fdd4802b409ef15300.jpg: cannot identify image file '/content/images1/0_jpg.rf.33492b06d74069fdd4802b409ef15300.jpg'
# Error processing image 0_jpg.rf.c8492b0a1c99aaa9f08feabdad30ab10.jpg: cannot identify image file '/content/images1/0_jpg.rf.c8492b0a1c99aaa9f08feabdad30ab10.jpg'

# %%
# !pip install Pillow

# %%
from PIL import Image

# %%
import os

if os.path.exists("/content/3.jpg"):
    print("File exists.")
else:
    print("File does not exist.")
# Out:
# File exists.

# %%
from PIL import Image

try:
    img = Image.open("/content/3.jpg")
    print("Image format:", img.format)
except Exception as e:
    print("Error opening image:", e)
# Out:
# Error opening image: cannot identify image file '/content/3.jpg'

# %%
im = Image.open("/content/3.jpg")
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-13-4331d2093577> in <cell line: 1>()
# ----> 1 im = Image.open("/content/3.jpg")
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3281                 raise
#    3282         return None
# -> 3283
#    3284     im = _open_core(fp, filename, prefix, formats)
#    3285
#
# UnidentifiedImageError: cannot identify image file '/content/3.jpg'

# %%
img_path = '/content/3.jpg'
result = model(img_path)
result.show()
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-6-609489f93cec> in <cell line: 2>()
#       1 img_path = '/content/3.jpg'
# ----> 2 result = model(img_path)
#       3 result.show()
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
# ...

# %%
from PIL import Image

try:
    img = Image.open(img_path)
    print("Image format:", img.format)
except Exception as e:
    print("Error opening image:", e)
# Out:
# Error opening image: cannot identify image file '/content/21.jpg'

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="XRcZB4HVUZw2RzVGB0EV")
project = rf.workspace("ahmad-essam-gvgib").project("numbers-recognition")
dataset = project.version(10).download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov5pytorch in progress : 85.0%
# Version export complete for yolov5pytorch format
# ...
# Extracting Dataset Version Zip to numbers-recognition-10 in yolov5pytorch:: 100%|██████████| 3355/3355 [00:00<00:00, 6700.52it/s]

# %%
os.environ["DATASET_DIRECTORY"] = "/content/dataset"

# %%
# !python train.py --img 416 --batch 16 --epochs 50 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# 2023-11-22 05:54:03.081603: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-22 05:54:03.081675: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-22 05:54:03.081717: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 50 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# 2023-11-22 12:51:17.483650: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-22 12:51:17.483707: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-22 12:51:17.483747: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 50 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# 2023-11-22 17:32:12.155177: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-22 17:32:12.155247: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-22 17:32:12.155295: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 50 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# 2023-11-22 20:21:28.722228: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-22 20:21:28.722303: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-22 20:21:28.722348: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 50 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# 2023-11-23 07:30:59.021903: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-23 07:30:59.021965: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-23 07:30:59.022007: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 50 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# 2023-11-23 09:43:08.763245: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-23 09:43:08.763308: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-23 09:43:08.763357: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 50 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# 2023-11-24 14:50:01.442047: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-24 14:50:01.442103: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-24 14:50:01.442149: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 50 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# 2023-11-24 19:08:28.143480: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-24 19:08:28.143544: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-24 19:08:28.143591: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 100 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# 2023-11-25 04:46:17.251907: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-25 04:46:17.251977: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-25 04:46:17.252023: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 50 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# 2023-11-25 09:14:12.567231: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-25 09:14:12.567292: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-25 09:14:12.567332: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
